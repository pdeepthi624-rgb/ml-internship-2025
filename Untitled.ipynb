# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Wj826uI6dgjGzFdLZGBn")
project = rf.workspace("developer-3yo81").project("car-dectection-hsxwz")
version = project.version(2)
dataset = version.download("coco")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to car-dectection-2 in coco:: 100%|████████████████████| 17/17 [00:00<00:00, 178.38it/s]

# %%
# Install Roboflow
# !pip install roboflow

# Import necessary modules
from roboflow import Roboflow
import matplotlib.pyplot as plt
import cv2
import os

# Connect to Roboflow and download dataset
rf = Roboflow(api_key="Wj826uI6dgjGzFdLZGBn")
project = rf.workspace("developer-3yo81").project("car-dectection-hsxwz")
version = project.version(1)
dataset = version.download("coco")  # This downloads the dataset

# Set path to downloaded images
image_dir = os.path.join(dataset.location, "train")

# List all image files
image_files = [f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]

# Display a few images using matplotlib
for i in range(5):  # Change number to display more/less
    img_path = os.path.join(image_dir, image_files[i])
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(6, 6))
    plt.imshow(img)
# Out:
# ...
# Matplotlib is building the font cache; this may take a moment.
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format coco in progress : 85.0%
# Version export complete for coco format
# ...
# Extracting Dataset Version Zip to car-dectection-1 in coco:: 100%|████████████████████| 17/17 [00:00<00:00, 217.87it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Wj826uI6dgjGzFdLZGBn")
project = rf.workspace("developer-3yo81").project("iris-flower-sh0qn")
version = project.version(1)
dataset = version.download("coco")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Wj826uI6dgjGzFdLZGBn")
project = rf.workspace("developer-3yo81").project("iris-flower-oxdjw")
version = project.version(2)
dataset = version.download("coco")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to iris-flower-2 in coco:: 100%|███████████████████████| 12/12 [00:00<00:00, 163.84it/s]

# %%
import os

image_dir = os.path.join(dataset.location, "train")

if not os.path.exists(image_dir):
    print("Directory not found:", image_dir)
else:
    print("Directory found!")
# Out:
# Directory not found: C:\Users\HP\OneDrive\Desktop\internship jupiterking\iris-flower-1\train
